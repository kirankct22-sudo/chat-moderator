# %% [markdown]
# <a href="https://colab.research.google.com/github/kirankct22-sudo/chat-moderator/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
days=[1,2,3,4,5]
sales=[100,120,140,130,160]

plt.plot(days,sales)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.title("Titile")
# Out:
# Text(0.5, 1.0, 'Titile')

# %%
import matplotlib.pyplot as plt

subjects =["maths","physics","chemistry"]
marks = [80,92,75]
plt.bar(subjects,marks)
plt.title ("marks" in "subject")
plt .xlabel("subjects")
plt.ylabel("marks")
plt.show()

# %%
import matplotlib.pyplot as plt
subjects = ["maths","physics","chemistry"]
marks=[80,92,75]

plt.barh(subjects,marks)
pltr.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_626/1965892889.py in <cell line: 0>()
#       4
#       5 plt.barh(subjects,marks)
# ----> 6 pltr.show()
#
# NameError: name 'pltr' is not defined

# %%
import matplotlib.pyplot as plt
subjects = ["maths","physics","chemistry","english"]
marks=[10,20,30,40]

plt.pie(marks,labels=subjects)
pltr.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_626/2476105717.py in <cell line: 0>()
#       4
#       5 plt.pie(marks,labels=subjects)
# ----> 6 pltr.show()
#
# NameError: name 'pltr' is not defined
