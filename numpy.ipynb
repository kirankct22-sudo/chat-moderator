# %% [markdown]
# <a href="https://colab.research.google.com/github/kirankct22-sudo/chat-moderator/blob/main/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.array([10,20,30,40])
print(a[0])
print (a[2])
# Out:
# 10
# 30

# %%
import numpy as np
a =  np.array([10,20,30,40])
print(a)
# Out:
# [10 20 30 40]

# %%
import numpy as np
a= np.array([
    [1,2,3],
    [4,5,6]
])
print(a)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np
a = np.array([

              [1,2,3],
              [4,5,6]
])
print(a.shape)
# Out:
# (2, 3)

# %%
import numpy as np

a=np.zeros(5)
print(a)
# Out:
# [0. 0. 0. 0. 0.]

# %%
import numpy as np
a=np.ones(5)
print(a)
# Out:
# [1. 1. 1. 1. 1.]

# %%
import numpy as np
a=np.arange(1,10,2)
print(a)
# Out:
# [1 3 5 7 9]

# %%
import numpy as np
a=np.array([1,2,3,4])
print(a+5)
# Out:
# [6 7 8 9]

# %%
import numpy as np
a=np.array([10,20,30,40])
print(np.sum(a))
# Out:
# 100

# %%
import numpy as np
a=np.array([10,20,30,40])
print(np.min(a))
print (np.max(a))
# Out:
# 10
# 40

# %%
import numpy as np
a=np.array([10,20,30,40])
print(np.mean(a))
# Out:
# 25.0

# %%
import numpy as np
a=np.array([10,20,30,40,50])
print(a[1:4])
# Out:
# [20 30 40]
